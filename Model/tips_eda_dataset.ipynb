# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/KOSA-Big-Data_Vision/blob/main/Model/tips_eda_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U pandas-profiling

# %%
import pandas_profiling

# %%
import pandas as pd

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sex_type = {'Female':0, 'Male':1}

# %%
df['sex'].replace(sex_type, inplace=True)

# %%
df['sex'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: sex, dtype: int64

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
smoker_type = {'No':0, 'Yes':1}

# %%
df['smoker'].replace(smoker_type, inplace=True)

# %%
df['smoker'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: smoker, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
day_type = {'Thur':0, 'Fri':1, 'Sat':2, 'Sun':3 }

# %%
df['day'].replace(day_type, inplace=True)

# %%
df['day'].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: day, dtype: int64

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
time_type = {'Lunch':0, 'Dinner':1}

# %%
df['time'].replace(time_type, inplace=True)

# %%
df['time'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: time, dtype: int64

# %%
# Mutate variable

# %%
df['tip_rate'] = (df['tip']/df['total_bill'])*100

# %%
df.corr(method='pearson')
# Out:
#             total_bill       tip       sex  ...      time      size  tip_rate
# total_bill    1.000000  0.675734  0.144877  ...  0.183118  0.598315 -0.338624
# tip           0.675734  1.000000  0.088862  ...  0.121629  0.489299  0.342370
# sex           0.144877  0.088862  1.000000  ...  0.205231  0.086195 -0.069475
# smoker        0.085721  0.005929  0.002816  ...  0.054921 -0.133178  0.030820
# day           0.173693  0.135499  0.230791  ...  0.874366  0.165350  0.013493
# time          0.183118  0.121629  0.205231  ...  1.000000  0.103411 -0.033914
# size          0.598315  0.489299  0.086195  ...  0.103411  1.000000 -0.142860
# tip_rate     -0.338624  0.342370 -0.069475  ... -0.033914 -0.142860  1.000000
#
# [8 rows x 8 columns]

# %%
df.describe()
# Out:
#        total_bill         tip         sex  ...        time        size    tip_rate
# count  244.000000  244.000000  244.000000  ...  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.643443  ...    0.721311    2.569672   16.080258
# std      8.902412    1.383638    0.479967  ...    0.449276    0.951100    6.107220
# min      3.070000    1.000000    0.000000  ...    0.000000    1.000000    3.563814
# 25%     13.347500    2.000000    0.000000  ...    0.000000    2.000000   12.912736
# 50%     17.795000    2.900000    1.000000  ...    1.000000    2.000000   15.476977
# 75%     24.127500    3.562500    1.000000  ...    1.000000    3.000000   19.147549
# max     50.810000   10.000000    1.000000  ...    1.000000    6.000000   71.034483
#
# [8 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'tip_rate'],
#       dtype='object')

# %%
col_list = list(df.columns)

# %%
col_list = ['total_bill', 'tip', 'tip_rate', 'sex', 'smoker', 'day', 'time', 'size']

# %%
col_list
# Out:
# ['total_bill', 'tip', 'tip_rate', 'sex', 'smoker', 'day', 'time', 'size']

# %%
df_altered = df[col_list]

# %%
df_another = df[['total_bill', 'tip', 'tip_rate', 'sex', 'smoker', 'day', 'time', 'size']]

# %%
df_another.describe()
# Out:
#        total_bill         tip    tip_rate  ...         day        time        size
# count  244.000000  244.000000  244.000000  ...  244.000000  244.000000  244.000000
# mean    19.785943    2.998279   16.080258  ...    1.725410    0.721311    2.569672
# std      8.902412    1.383638    6.107220  ...    1.155774    0.449276    0.951100
# min      3.070000    1.000000    3.563814  ...    0.000000    0.000000    1.000000
# 25%     13.347500    2.000000   12.912736  ...    0.000000    0.000000    2.000000
# 50%     17.795000    2.900000   15.476977  ...    2.000000    1.000000    2.000000
# 75%     24.127500    3.562500   19.147549  ...    3.000000    1.000000    3.000000
# max     50.810000   10.000000   71.034483  ...    3.000000    1.000000    6.000000
#
# [8 rows x 8 columns]

# %%
df_altered.describe()
# Out:
#        total_bill         tip    tip_rate  ...         day        time        size
# count  244.000000  244.000000  244.000000  ...  244.000000  244.000000  244.000000
# mean    19.785943    2.998279   16.080258  ...    1.725410    0.721311    2.569672
# std      8.902412    1.383638    6.107220  ...    1.155774    0.449276    0.951100
# min      3.070000    1.000000    3.563814  ...    0.000000    0.000000    1.000000
# 25%     13.347500    2.000000   12.912736  ...    0.000000    0.000000    2.000000
# 50%     17.795000    2.900000   15.476977  ...    2.000000    1.000000    2.000000
# 75%     24.127500    3.562500   19.147549  ...    3.000000    1.000000    3.000000
# max     50.810000   10.000000   71.034483  ...    3.000000    1.000000    6.000000
#
# [8 rows x 8 columns]

# %%
type(col_list)
# Out:
# list

# %%
import seaborn as sns

# %%
sns.pairplot(df_altered.loc[:,['total_bill','tip']])

# %%
sns.pairplot(df_altered.loc[:,['tip_rate','tip']])

# %%
sns.pairplot(df_altered.loc[:,['tip_rate','total_bill']])

# %%
df_altered.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-15 01:39:35.590457&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-15 01:24:54.952171&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_altered.corr(method='pearson')
# Out:
#             total_bill       tip  tip_rate  ...       day      time      size
# total_bill    1.000000  0.675734 -0.338624  ...  0.173693  0.183118  0.598315
# tip           0.675734  1.000000  0.342370  ...  0.135499  0.121629  0.489299
# tip_rate     -0.338624  0.342370  1.000000  ...  0.013493 -0.033914 -0.142860
# sex           0.144877  0.088862 -0.069475  ...  0.230791  0.205231  0.086195
# smoker        0.085721  0.005929  0.030820  ... -0.032653  0.054921 -0.133178
# day           0.173693  0.135499  0.013493  ...  1.000000  0.874366  0.165350
# time          0.183118  0.121629 -0.033914  ...  0.874366  1.000000  0.103411
# size          0.598315  0.489299 -0.142860  ...  0.165350  0.103411  1.000000
#
# [8 rows x 8 columns]

# %%
# 목표변수
# 1. 성별에 따른 예상매출(Total Bill) -> 목표변수 - total_bill
# 2. 요일별 예상 매출 -> 목표변수 - total_bill
# 3. 팁이 가장 많은 요일 -> 목표변수 - tip
# 4. 요일별 방문객수(팀) -> 목표변수 - size
